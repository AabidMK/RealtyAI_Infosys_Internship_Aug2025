# %%
#importing libraries
import pandas as pd
from prophet import Prophet
import pickle
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
 # Load the dataset
df = pd.read_csv("/content/State_time_series.csv")

# %%
# checking the datatype of  date column
print(df['Date'].dtype)
# Out:
# object

# %%
print(df.columns.tolist())
# Out:
# ['Date', 'RegionName', 'DaysOnZillow_AllHomes', 'InventorySeasonallyAdjusted_AllHomes', 'InventoryRaw_AllHomes', 'MedianListingPricePerSqft_1Bedroom', 'MedianListingPricePerSqft_2Bedroom', 'MedianListingPricePerSqft_3Bedroom', 'MedianListingPricePerSqft_4Bedroom', 'MedianListingPricePerSqft_5BedroomOrMore', 'MedianListingPricePerSqft_AllHomes', 'MedianListingPricePerSqft_CondoCoop', 'MedianListingPricePerSqft_DuplexTriplex', 'MedianListingPricePerSqft_SingleFamilyResidence', 'MedianListingPrice_1Bedroom', 'MedianListingPrice_2Bedroom', 'MedianListingPrice_3Bedroom', 'MedianListingPrice_4Bedroom', 'MedianListingPrice_5BedroomOrMore', 'MedianListingPrice_AllHomes', 'MedianListingPrice_CondoCoop', 'MedianListingPrice_DuplexTriplex', 'MedianListingPrice_SingleFamilyResidence', 'MedianPctOfPriceReduction_AllHomes', 'MedianPctOfPriceReduction_CondoCoop', 'MedianPctOfPriceReduction_SingleFamilyResidence', 'MedianPriceCutDollar_AllHomes', 'MedianPriceCutDollar_CondoCoop', 'MedianPriceCutDollar_SingleFamilyResidence', 'MedianRentalPricePerSqft_1Bedroom', 'MedianRentalPricePerSqft_2Bedroom', 'MedianRentalPricePerSqft_3Bedroom', 'MedianRentalPricePerSqft_4Bedroom', 'MedianRentalPricePerSqft_5BedroomOrMore', 'MedianRentalPricePerSqft_AllHomes', 'MedianRentalPricePerSqft_CondoCoop', 'MedianRentalPricePerSqft_DuplexTriplex', 'MedianRentalPricePerSqft_MultiFamilyResidence5PlusUnits', 'MedianRentalPricePerSqft_SingleFamilyResidence', 'MedianRentalPricePerSqft_Studio', 'MedianRentalPrice_1Bedroom', 'MedianRentalPrice_2Bedroom', 'MedianRentalPrice_3Bedroom', 'MedianRentalPrice_4Bedroom', 'MedianRentalPrice_5BedroomOrMore', 'MedianRentalPrice_AllHomes', 'MedianRentalPrice_CondoCoop', 'MedianRentalPrice_DuplexTriplex', 'MedianRentalPrice_MultiFamilyResidence5PlusUnits', 'MedianRentalPrice_SingleFamilyResidence', 'MedianRentalPrice_Studio', 'ZHVIPerSqft_AllHomes', 'PctOfHomesDecreasingInValues_AllHomes', 'PctOfHomesIncreasingInValues_AllHomes', 'PctOfHomesSellingForGain_AllHomes', 'PctOfHomesSellingForLoss_AllHomes', 'PctOfListingsWithPriceReductionsSeasAdj_AllHomes', 'PctOfListingsWithPriceReductionsSeasAdj_CondoCoop', 'PctOfListingsWithPriceReductionsSeasAdj_SingleFamilyResidence', 'PctOfListingsWithPriceReductions_AllHomes', 'PctOfListingsWithPriceReductions_CondoCoop', 'PctOfListingsWithPriceReductions_SingleFamilyResidence', 'PriceToRentRatio_AllHomes', 'Sale_Counts', 'Sale_Counts_Seas_Adj', 'Sale_Prices', 'ZHVI_1bedroom', 'ZHVI_2bedroom', 'ZHVI_3bedroom', 'ZHVI_4bedroom', 'ZHVI_5BedroomOrMore', 'ZHVI_AllHomes', 'ZHVI_BottomTier', 'ZHVI_CondoCoop', 'ZHVI_MiddleTier', 'ZHVI_SingleFamilyResidence', 'ZHVI_TopTier', 'ZRI_AllHomes', 'ZRI_AllHomesPlusMultifamily', 'ZriPerSqft_AllHomes', 'Zri_MultiFamilyResidenceRental', 'Zri_SingleFamilyResidenceRental']

# %%
#converting the object type in to datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
multi_df = df[['Date', 'RegionName', 'ZHVI_AllHomes']].copy()
multi_df.sort_values(['RegionName', 'Date'], inplace=True)

# Interpolate missing values per state
# so basically interpolate fills out the missing values using the surrounding data values
multi_df['ZHVI_AllHomes'] = (
    multi_df
    .groupby('RegionName')['ZHVI_AllHomes']#by using groupby we treat each region separately
    .transform(lambda g: g.interpolate(method='linear'))
)

# %%
multi_df.isnull().sum()
# Out:
# Date               1
# RegionName         1
# ZHVI_AllHomes    691
# dtype: int64

# %%
#using rolling method to handle outliers
# here we replace the extreme outliers by using the below function with smoothed median values
def rolling_median(series, window=3, threshold=3):
    roll_med = series.rolling(window=window, center=True, min_periods=1).median()
    diff = (series - roll_med).abs()
    mad = diff.rolling(window=window, center=True, min_periods=1).median()
    return series.where(diff <= threshold * mad, roll_med)

multi_df['ZHVI_AllHomes'] = (
    multi_df
    .groupby('RegionName')['ZHVI_AllHomes']
    .transform(lambda s: rolling_median(s))
)

# %%
print(multi_df.head(20))
print(multi_df.info())
# Out:
#           Date RegionName  ZHVI_AllHomes
# 0   1996-04-30    Alabama        79500.0
# 44  1996-05-31    Alabama        79200.0
# 90  1996-06-30    Alabama        79500.0
# 136 1996-07-31    Alabama        79700.0
# 182 1996-08-31    Alabama        79700.0
# 228 1996-09-30    Alabama        79700.0
# 274 1996-10-31    Alabama        80100.0
# 320 1996-11-30    Alabama        80600.0
# 366 1996-12-31    Alabama        80800.0
# 412 1997-01-31    Alabama        80700.0
# 458 1997-02-28    Alabama        80900.0
# 504 1997-03-31    Alabama        81300.0
# 550 1997-04-30    Alabama        81300.0
# 596 1997-05-31    Alabama        80900.0
# 642 1997-06-30    Alabama        80900.0
# 688 1997-07-31    Alabama        81100.0
# 734 1997-08-31    Alabama        81400.0
# 780 1997-09-30    Alabama        81700.0
# 827 1997-10-31    Alabama        81800.0
# 874 1997-11-30    Alabama        81900.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 11016 entries, 0 to 11015
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           11015 non-null  datetime64[ns]
#  1   RegionName     11015 non-null  object
#  2   ZHVI_AllHomes  10332 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 344.2+ KB
# None

# %%
df['Date'] = pd.to_datetime(df['Date']) #checking date column again

# %%
output_dir = "prophet_outputs"
plot_dir = os.path.join(output_dir, "plots")
os.makedirs(output_dir, exist_ok=True)
os.makedirs(plot_dir, exist_ok=True)

# %%
regions = df['RegionName'].unique() #get all unique regions

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet
import os
import joblib
import io

# Save files directly in /content
csv_file = "/content/all_regions_forecast.csv"
data_joblib_file = "/content/all_forecasts_data.joblib"
plots_joblib_file = "/content/all_forecasts_plots.joblib"

def train_and_forecast(region_df, reg):
    if len(region_df) < 24:
        print(f"Skipping {reg} (not enough data)")
        return None, None

    # Prepare for Prophet
    region_df = region_df.rename(columns={'Date': 'ds', 'ZHVI_AllHomes': 'y'})
    model = Prophet(yearly_seasonality=True, weekly_seasonality=False, daily_seasonality=False)
    model.fit(region_df)

    future = model.make_future_dataframe(periods=12, freq='MS')
    forecast = model.predict(future)
    forecast['RegionName'] = reg


    fig1 = model.plot(forecast)
    plt.title(f"Forecast for {reg}")
    buf1 = io.BytesIO()
    fig1.savefig(buf1, format='png')
    plt.close(fig1)
    buf1.seek(0)

    fig2 = model.plot_components(forecast)
    buf2 = io.BytesIO()
    fig2.savefig(buf2, format='png')
    plt.close(fig2)
    buf2.seek(0)

    return forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'RegionName']], {
        'forecast_plot': buf1.getvalue(),
        'components_plot': buf2.getvalue()
    }

# Train for all regions
all_forecasts_list = []
all_plots_dict = {}
regions = df["RegionName"].dropna().unique()

for reg in regions:
    region_df = df[df["RegionName"] == reg][['Date', 'ZHVI_AllHomes']].dropna()
    result, plots = train_and_forecast(region_df, reg)
    if result is not None:
        all_forecasts_list.append(result)
        all_plots_dict[reg] = plots

all_forecasts = pd.concat(all_forecasts_list, ignore_index=True)

all_forecasts.to_csv(csv_file, index=False)
joblib.dump(all_forecasts, data_joblib_file)
joblib.dump(all_plots_dict, plots_joblib_file)

print(" All outputs saved successfully!")
print("Files available in the Files panel:")
print(csv_file)
print(data_joblib_file)
print(plots_joblib_file)

# Show the files in Colab Files section
# !ls -lh /content
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/7nxwzkyo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/viiomi1q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37152', 'data', 'file=/tmp/tmpq0x8v9xa/7nxwzkyo.json', 'init=/tmp/tmpq0x8v9xa/viiomi1q.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model341x8pki/prophet_model-20251005063331.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/sze_n7pv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/3qxk9y_d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93170', 'data', 'file=/tmp/tmpq0x8v9xa/sze_n7pv.json', 'init=/tmp/tmpq0x8v9xa/3qxk9y_d.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model2d_6gb9x/prophet_model-20251005063332.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/igwuiwyu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/ld3pquev.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47058', 'data', 'file=/tmp/tmpq0x8v9xa/igwuiwyu.json', 'init=/tmp/tmpq0x8v9xa/ld3pquev.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelvgpontwl/prophet_model-20251005063333.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/7fg95xzc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/4746t_6x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93421', 'data', 'file=/tmp/tmpq0x8v9xa/7fg95xzc.json', 'init=/tmp/tmpq0x8v9xa/4746t_6x.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model0sivf98w/prophet_model-20251005063334.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/h12gjxj5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/ji3m8_bz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50907', 'data', 'file=/tmp/tmpq0x8v9xa/h12gjxj5.json', 'init=/tmp/tmpq0x8v9xa/ji3m8_bz.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelg96og63q/prophet_model-20251005063336.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/yh1_yryz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/bshltzne.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84767', 'data', 'file=/tmp/tmpq0x8v9xa/yh1_yryz.json', 'init=/tmp/tmpq0x8v9xa/bshltzne.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelk2qkge39/prophet_model-20251005063337.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/3b1p79c7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/hc60w64j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30112', 'data', 'file=/tmp/tmpq0x8v9xa/3b1p79c7.json', 'init=/tmp/tmpq0x8v9xa/hc60w64j.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model69nao293/prophet_model-20251005063337.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/wx0qc7w0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/5n7vjdrl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28446', 'data', 'file=/tmp/tmpq0x8v9xa/wx0qc7w0.json', 'init=/tmp/tmpq0x8v9xa/5n7vjdrl.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelw82z5uzt/prophet_model-20251005063338.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_t93q8_j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_txleuve.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31961', 'data', 'file=/tmp/tmpq0x8v9xa/_t93q8_j.json', 'init=/tmp/tmpq0x8v9xa/_txleuve.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model8qq7ucqz/prophet_model-20251005063339.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/qj99ppj6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/km4sp1sb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54467', 'data', 'file=/tmp/tmpq0x8v9xa/qj99ppj6.json', 'init=/tmp/tmpq0x8v9xa/km4sp1sb.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelb8nogc9m/prophet_model-20251005063340.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/xr55_871.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/wfgtsuy9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52147', 'data', 'file=/tmp/tmpq0x8v9xa/xr55_871.json', 'init=/tmp/tmpq0x8v9xa/wfgtsuy9.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model2ocia_v9/prophet_model-20251005063340.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/t09vozuc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/8duv7fa4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42335', 'data', 'file=/tmp/tmpq0x8v9xa/t09vozuc.json', 'init=/tmp/tmpq0x8v9xa/8duv7fa4.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modeln9mq8f8o/prophet_model-20251005063341.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/2osjldc_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/cbbciqy9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13501', 'data', 'file=/tmp/tmpq0x8v9xa/2osjldc_.json', 'init=/tmp/tmpq0x8v9xa/cbbciqy9.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model4fti39ar/prophet_model-20251005063342.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/2yhr5gbq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/dnnxlg7w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70907', 'data', 'file=/tmp/tmpq0x8v9xa/2yhr5gbq.json', 'init=/tmp/tmpq0x8v9xa/dnnxlg7w.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelvx7ig7wh/prophet_model-20251005063343.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/kbu9yotl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/ji_e_2pe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31730', 'data', 'file=/tmp/tmpq0x8v9xa/kbu9yotl.json', 'init=/tmp/tmpq0x8v9xa/ji_e_2pe.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelj1s4nbrn/prophet_model-20251005063343.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:33:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/3ai5_kmc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/k4941a7c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32551', 'data', 'file=/tmp/tmpq0x8v9xa/3ai5_kmc.json', 'init=/tmp/tmpq0x8v9xa/k4941a7c.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelrz1g0isk/prophet_model-20251005063344.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_m4v8bl8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/2h6hm7kf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81948', 'data', 'file=/tmp/tmpq0x8v9xa/_m4v8bl8.json', 'init=/tmp/tmpq0x8v9xa/2h6hm7kf.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelify43ioi/prophet_model-20251005063346.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Skipping Louisiana (not enough data)
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/7e76fxre.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/ckyvg0s7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2443', 'data', 'file=/tmp/tmpq0x8v9xa/7e76fxre.json', 'init=/tmp/tmpq0x8v9xa/ckyvg0s7.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelfiva2xz8/prophet_model-20251005063347.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/aosru8id.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/j6y5pq3_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21262', 'data', 'file=/tmp/tmpq0x8v9xa/aosru8id.json', 'init=/tmp/tmpq0x8v9xa/j6y5pq3_.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelji_qik86/prophet_model-20251005063348.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/w__bm0o_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/e7n_dvmg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19003', 'data', 'file=/tmp/tmpq0x8v9xa/w__bm0o_.json', 'init=/tmp/tmpq0x8v9xa/e7n_dvmg.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model_noog3o3/prophet_model-20251005063348.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/x1fmmmkr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/apzzapmp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11331', 'data', 'file=/tmp/tmpq0x8v9xa/x1fmmmkr.json', 'init=/tmp/tmpq0x8v9xa/apzzapmp.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modeli9mgdnao/prophet_model-20251005063349.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/5ekxi5gv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/v67pg49w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99415', 'data', 'file=/tmp/tmpq0x8v9xa/5ekxi5gv.json', 'init=/tmp/tmpq0x8v9xa/v67pg49w.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model0k894fma/prophet_model-20251005063350.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_n_tns8s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/rmlzl6hg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30042', 'data', 'file=/tmp/tmpq0x8v9xa/_n_tns8s.json', 'init=/tmp/tmpq0x8v9xa/rmlzl6hg.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelle_h04ej/prophet_model-20251005063351.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/1smw99bz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/4fm08cf4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85056', 'data', 'file=/tmp/tmpq0x8v9xa/1smw99bz.json', 'init=/tmp/tmpq0x8v9xa/4fm08cf4.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelqu9koc1_/prophet_model-20251005063351.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/abi6iolb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/2_x0ok7f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75389', 'data', 'file=/tmp/tmpq0x8v9xa/abi6iolb.json', 'init=/tmp/tmpq0x8v9xa/2_x0ok7f.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modellh2_bbi3/prophet_model-20251005063352.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/ykqbbeaj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/l4pca10y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50491', 'data', 'file=/tmp/tmpq0x8v9xa/ykqbbeaj.json', 'init=/tmp/tmpq0x8v9xa/l4pca10y.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model2a7sxhjq/prophet_model-20251005063353.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/6b976xuz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/zinb4q3w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31339', 'data', 'file=/tmp/tmpq0x8v9xa/6b976xuz.json', 'init=/tmp/tmpq0x8v9xa/zinb4q3w.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model905j9itn/prophet_model-20251005063353.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/y9_fuosk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/yvnfma4b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62643', 'data', 'file=/tmp/tmpq0x8v9xa/y9_fuosk.json', 'init=/tmp/tmpq0x8v9xa/yvnfma4b.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelt4qo_wmd/prophet_model-20251005063354.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/7_ktt372.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/cn1gvi3r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41286', 'data', 'file=/tmp/tmpq0x8v9xa/7_ktt372.json', 'init=/tmp/tmpq0x8v9xa/cn1gvi3r.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modeltr49zqbx/prophet_model-20251005063355.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:33:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/l4jlwyad.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/px4bdkv6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42257', 'data', 'file=/tmp/tmpq0x8v9xa/l4jlwyad.json', 'init=/tmp/tmpq0x8v9xa/px4bdkv6.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelldodxw4_/prophet_model-20251005063356.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/oawbozdn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/6y6nmd1o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64514', 'data', 'file=/tmp/tmpq0x8v9xa/oawbozdn.json', 'init=/tmp/tmpq0x8v9xa/6y6nmd1o.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modely642x_wy/prophet_model-20251005063357.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/v9fvft1l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/wkla_nq_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=391', 'data', 'file=/tmp/tmpq0x8v9xa/v9fvft1l.json', 'init=/tmp/tmpq0x8v9xa/wkla_nq_.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model2sfcdolt/prophet_model-20251005063357.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/x0jm7bww.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/3qfc3p_s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12503', 'data', 'file=/tmp/tmpq0x8v9xa/x0jm7bww.json', 'init=/tmp/tmpq0x8v9xa/3qfc3p_s.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modeln6z6uffg/prophet_model-20251005063359.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:33:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:33:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/xrrndvm1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/ewvl1oqz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12211', 'data', 'file=/tmp/tmpq0x8v9xa/xrrndvm1.json', 'init=/tmp/tmpq0x8v9xa/ewvl1oqz.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model77w1pphe/prophet_model-20251005063400.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/8mn0gztr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/f8gh5hfq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24388', 'data', 'file=/tmp/tmpq0x8v9xa/8mn0gztr.json', 'init=/tmp/tmpq0x8v9xa/f8gh5hfq.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modeld7dlbbmi/prophet_model-20251005063401.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/6pcuvywi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/avk0ri7d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79263', 'data', 'file=/tmp/tmpq0x8v9xa/6pcuvywi.json', 'init=/tmp/tmpq0x8v9xa/avk0ri7d.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelfbl11rzc/prophet_model-20251005063401.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/wx_4lkvu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/ihocdqgz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75940', 'data', 'file=/tmp/tmpq0x8v9xa/wx_4lkvu.json', 'init=/tmp/tmpq0x8v9xa/ihocdqgz.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model5krf74kv/prophet_model-20251005063402.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_6nlzaln.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/9beev9uj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84480', 'data', 'file=/tmp/tmpq0x8v9xa/_6nlzaln.json', 'init=/tmp/tmpq0x8v9xa/9beev9uj.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modeld87u4c8i/prophet_model-20251005063403.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/yolp1fxi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_1s6scsd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85111', 'data', 'file=/tmp/tmpq0x8v9xa/yolp1fxi.json', 'init=/tmp/tmpq0x8v9xa/_1s6scsd.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelno2o_ept/prophet_model-20251005063404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/a7ajgxbn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/yjiumfi3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19685', 'data', 'file=/tmp/tmpq0x8v9xa/a7ajgxbn.json', 'init=/tmp/tmpq0x8v9xa/yjiumfi3.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model1gyheh3q/prophet_model-20251005063404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/sy42vw29.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/go1h9ddw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=634', 'data', 'file=/tmp/tmpq0x8v9xa/sy42vw29.json', 'init=/tmp/tmpq0x8v9xa/go1h9ddw.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modeliv9vtuk1/prophet_model-20251005063405.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/rtkge5n8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/s2dhs_fa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2470', 'data', 'file=/tmp/tmpq0x8v9xa/rtkge5n8.json', 'init=/tmp/tmpq0x8v9xa/s2dhs_fa.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelo324bohh/prophet_model-20251005063406.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/doupi102.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_ulpeuah.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17501', 'data', 'file=/tmp/tmpq0x8v9xa/doupi102.json', 'init=/tmp/tmpq0x8v9xa/_ulpeuah.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model8dzp04ef/prophet_model-20251005063407.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/rt83oyti.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/wao9r6cd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98991', 'data', 'file=/tmp/tmpq0x8v9xa/rt83oyti.json', 'init=/tmp/tmpq0x8v9xa/wao9r6cd.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_model4udw54lz/prophet_model-20251005063407.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/cxhq4s0a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/mh5imzbq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87898', 'data', 'file=/tmp/tmpq0x8v9xa/cxhq4s0a.json', 'init=/tmp/tmpq0x8v9xa/mh5imzbq.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_models3fjtdum/prophet_model-20251005063408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/yya_dgzu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/0vg0oevz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89480', 'data', 'file=/tmp/tmpq0x8v9xa/yya_dgzu.json', 'init=/tmp/tmpq0x8v9xa/0vg0oevz.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelfhzpgz6p/prophet_model-20251005063409.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/31c5lpyg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/_79ez_lo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73991', 'data', 'file=/tmp/tmpq0x8v9xa/31c5lpyg.json', 'init=/tmp/tmpq0x8v9xa/_79ez_lo.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelujc7w_h3/prophet_model-20251005063409.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/39av6mc_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/aq8gnamj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27461', 'data', 'file=/tmp/tmpq0x8v9xa/39av6mc_.json', 'init=/tmp/tmpq0x8v9xa/aq8gnamj.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelre24pfrm/prophet_model-20251005063410.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/tuzae2m0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/nmckmzub.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82153', 'data', 'file=/tmp/tmpq0x8v9xa/tuzae2m0.json', 'init=/tmp/tmpq0x8v9xa/nmckmzub.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelnaqsn7tf/prophet_model-20251005063411.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/p4u1uug6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpq0x8v9xa/7yapcewq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59557', 'data', 'file=/tmp/tmpq0x8v9xa/p4u1uug6.json', 'init=/tmp/tmpq0x8v9xa/7yapcewq.json', 'output', 'file=/tmp/tmpq0x8v9xa/prophet_modelsuavsump/prophet_model-20251005063412.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:34:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:34:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Skipping UnitedStates (not enough data)
#  All outputs saved successfully!
# Files available in the Files panel:
# /content/all_regions_forecast.csv
# /content/all_forecasts_data.joblib
# /content/all_forecasts_plots.joblib
# total 11M
# -rw-r--r-- 1 root root 365K Oct  5 06:34 all_forecasts_data.joblib
# -rw-r--r-- 1 root root 6.4M Oct  5 06:34 all_forecasts_plots.joblib
# -rw-r--r-- 1 root root 813K Oct  5 06:34 all_regions_forecast.csv
# drwxr-xr-x 2 root root 4.0K Oct  5 06:24 forecast_outputs
# drwxr-xr-x 2 root root 4.0K Oct  5 06:24 forecast_plots
# drwxr-xr-x 3 root root 4.0K Oct  5 06:19 prophet_outputs
# drwxr-xr-x 1 root root 4.0K Oct  2 13:36 sample_data
# -rw-r--r-- 1 root root 3.0M Oct  5 06:19 State_time_series.csv

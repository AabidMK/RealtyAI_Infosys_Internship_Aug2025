# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Real Estate Data V21.csv")
df
# Out:
#                                                     Name  \
# 0                                       Casagrand ECR 14
# 1                  Ramanathan Nagar, Pozhichalur,Chennai
# 2                                            DAC Prapthi
# 3                Naveenilaya,Chepauk, Triplicane,Chennai
# 4                               VGN Spring Field Phase 1
# ...                                                  ...
# 14523      Krishna Park Extension, Tilak Nagar,New Delhi
# 14524                   Rawta, Jaffarpur Kalan,New Delhi
# 14525                Rani Garden, Geeta Colony,New Delhi
# 14526  Lig flat rohini,Sector 16E, Sector 16 Rohini,N...
# 14527               Sector 3B, Sector 3 Rohini,New Delhi
#
#                                           Property Title     Price  \
# 0      4 BHK Flat for sale in Kanathur Reddikuppam, C...  ₹1.99 Cr
# 1      10 BHK Independent House for sale in Pozhichal...  ₹2.25 Cr
# 2          3 BHK Flat for sale in West Tambaram, Chennai   ₹1.0 Cr
# 3      7 BHK Independent House for sale in Triplicane...  ₹3.33 Cr
# 4                  2 BHK Flat for sale in Avadi, Chennai   ₹48.0 L
# ...                                                  ...       ...
# 14523      2 BHK Flat for sale in Tilak Nagar, New Delhi   ₹40.0 L
# 14524  1 BHK Independent House for sale in Jaffarpur ...   ₹14.0 L
# 14525     1 BHK Flat for sale in Geeta Colony, New Delhi   ₹30.0 L
# 14526  3 BHK Flat for sale in Sector 16 Rohini, New D...   ₹60.0 L
# 14527  1 RK Independent House for sale in Sector 3 Ro...   ₹55.0 L
#
#                                                 Location  Total_Area  \
# 0                          Kanathur Reddikuppam, Chennai        2583
# 1                  Ramanathan Nagar, Pozhichalur,Chennai        7000
# 2               Kasthuribai Nagar, West Tambaram,Chennai        1320
# 3                Naveenilaya,Chepauk, Triplicane,Chennai        4250
# 4                                         Avadi, Chennai         960
# ...                                                  ...         ...
# 14523      Krishna Park Extension, Tilak Nagar,New Delhi        1053
# 14524                   Rawta, Jaffarpur Kalan,New Delhi         472
# 14525                Rani Garden, Geeta Colony,New Delhi         378
# 14526  Lig flat rohini,Sector 16E, Sector 16 Rohini,N...         700
# 14527               Sector 3B, Sector 3 Rohini,New Delhi         344
#
#        Price_per_SQFT                                        Description  \
# 0              7700.0  Best 4 BHK Apartment for modern-day lifestyle ...
# 1              3210.0  Looking for a 10 BHK Independent House for sal...
# 2              7580.0  Property for sale in Tambaram, Chennai. This 3...
# 3              7840.0  Entire Building for sale with 7 units of singl...
# 4              5000.0  Property for sale in Avadi, Chennai. This 2 BH...
# ...               ...                                                ...
# 14523          3800.0  Looking for a good 2 BHK Apartment in Tilak Na...
# 14524          2970.0  1 BHK Independent House for sale in Jaffarpur ...
# 14525          7940.0  Property for sale in Geeta Colony, Delhi. This...
# 14526          8570.0  Check out this 3 BHK Apartment for sale in Roh...
# 14527         15990.0  This is an independent DDA house(in raw condit...
#
#        Baths Balcony
# 0          4     Yes
# 1          6     Yes
# 2          3      No
# 3          5     Yes
# 4          3     Yes
# ...      ...     ...
# 14523      3     Yes
# 14524      2     Yes
# 14525      1     Yes
# 14526      2     Yes
# 14527      1     Yes
#
# [14528 rows x 9 columns]

# %%
df['Description']
# Out:
# 0        Best 4 BHK Apartment for modern-day lifestyle ...
# 1        Looking for a 10 BHK Independent House for sal...
# 2        Property for sale in Tambaram, Chennai. This 3...
# 3        Entire Building for sale with 7 units of singl...
# 4        Property for sale in Avadi, Chennai. This 2 BH...
#                                ...
# 14523    Looking for a good 2 BHK Apartment in Tilak Na...
# 14524    1 BHK Independent House for sale in Jaffarpur ...
# 14525    Property for sale in Geeta Colony, Delhi. This...
# 14526    Check out this 3 BHK Apartment for sale in Roh...
# 14527    This is an independent DDA house(in raw condit...
# Name: Description, Length: 14528, dtype: object

# %%
# !pip install spacy
import spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.8.3)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
col=df['Description']
print(col)
print(col[0])
# Out:
# 0        Best 4 BHK Apartment for modern-day lifestyle ...
# 1        Looking for a 10 BHK Independent House for sal...
# 2        Property for sale in Tambaram, Chennai. This 3...
# 3        Entire Building for sale with 7 units of singl...
# 4        Property for sale in Avadi, Chennai. This 2 BH...
#                                ...
# 14523    Looking for a good 2 BHK Apartment in Tilak Na...
# 14524    1 BHK Independent House for sale in Jaffarpur ...
# 14525    Property for sale in Geeta Colony, Delhi. This...
# 14526    Check out this 3 BHK Apartment for sale in Roh...
# 14527    This is an independent DDA house(in raw condit...
# Name: Description, Length: 14528, dtype: object
# Best 4 BHK Apartment for modern-day lifestyle is now available for sale. No brokerage involved, Posted by Owner. Grab this 4 BHK property for sale in one of Chennai's top location, Kanathur Reddikuppam. It is situated on floor 13. The total number of floors in this Apartment is 14. The property price of this unit is Rs 1.99 Cr. The built-up area is 2583 Square feet. There are 4 bedrooms and 4 bathroom. It is an ideal location for young families with kids, as this property is close to Mount Litera Zee School, OMR, Chennai, Amelio Early Education - Siruseri, and Chennai Mathematical Institute. H...

# %%
doc=nlp(col[0])
print(doc)
# Out:
# Best 4 BHK Apartment for modern-day lifestyle is now available for sale. No brokerage involved, Posted by Owner. Grab this 4 BHK property for sale in one of Chennai's top location, Kanathur Reddikuppam. It is situated on floor 13. The total number of floors in this Apartment is 14. The property price of this unit is Rs 1.99 Cr. The built-up area is 2583 Square feet. There are 4 bedrooms and 4 bathroom. It is an ideal location for young families with kids, as this property is close to Mount Litera Zee School, OMR, Chennai, Amelio Early Education - Siruseri, and Chennai Mathematical Institute. H...

# %%
for token in doc:
    print(token.text, "| POS:", token.pos_, "| Lemma:", token.lemma_)
    print()
# Out:
# Best | POS: ADV | Lemma: well
#
# 4 | POS: NUM | Lemma: 4
#
# BHK | POS: PROPN | Lemma: BHK
#
# Apartment | POS: PROPN | Lemma: Apartment
#
# for | POS: ADP | Lemma: for
#
# modern | POS: ADJ | Lemma: modern
#
# - | POS: PUNCT | Lemma: -
#
# day | POS: NOUN | Lemma: day
#
# lifestyle | POS: NOUN | Lemma: lifestyle
#
# is | POS: AUX | Lemma: be
#
# now | POS: ADV | Lemma: now
#
# available | POS: ADJ | Lemma: available
#
# for | POS: ADP | Lemma: for
#
# sale | POS: NOUN | Lemma: sale
#
# . | POS: PUNCT | Lemma: .
#
# No | POS: DET | Lemma: no
#
# brokerage | POS: NOUN | Lemma: brokerage
#
# involved | POS: VERB | Lemma: involve
#
# , | POS: PUNCT | Lemma: ,
#
# Posted | POS: VERB | Lemma: post
#
# by | POS: ADP | Lemma: by
#
# Owner | POS: PROPN | Lemma: Owner
#
# . | POS: PUNCT | Lemma: .
#
# Grab | POS: VERB | Lemma: grab
#
# this | POS: DET | Lemma: this
#
# 4 | POS: NUM | Lemma: 4
#
# BHK | POS: PROPN | Lemma: BHK
#
# property | POS: NOUN | Lemma: property
#
# for | POS: ADP | Lemma: for
#
# sale | POS: NOUN | Lemma: sale
#
# in | POS: ADP | Lemma: in
#
# one | POS: NUM | Lemma: one
#
# of | POS: ADP | Lemma: of
#
# Chennai | POS: PROPN | Lemma: Chennai
#
# 's | POS: PART | Lemma: 's
#
# top | POS: ADJ | Lemma: top
#
# location | POS: NOUN | Lemma: location
#
# , | POS: PUNCT | Lemma: ,
#
# Kanathur | POS: PROPN | Lemma: Kanathur
#
# Reddikuppam | POS: PROPN | Lemma: Reddikuppam
#
# . | POS: PUNCT | Lemma: .
#
# It | POS: PRON | Lemma: it
#
# is | POS: AUX | Lemma: be
#
# situated | POS: VERB | Lemma: situate
#
# on | POS: ADP | Lemma: on
#
# floor | POS: NOUN | Lemma: floor
#
# 13 | POS: NUM | Lemma: 13
#
# . | POS: PUNCT | Lemma: .
#
# The | POS: DET | Lemma: the
#
# total | POS: ADJ | Lemma: total
#
# number | POS: NOUN | Lemma: number
#
# of | POS: ADP | Lemma: of
#
# floors | POS: NOUN | Lemma: floor
#
# in | POS: ADP | Lemma: in
#
# this | POS: DET | Lemma: this
#
# Apartment | POS: NOUN | Lemma: apartment
#
# is | POS: AUX | Lemma: be
#
# 14 | POS: NUM | Lemma: 14
#
# . | POS: PUNCT | Lemma: .
#
# The | POS: DET | Lemma: the
#
# property | POS: NOUN | Lemma: property
#
# price | POS: NOUN | Lemma: price
#
# of | POS: ADP | Lemma: of
#
# this | POS: DET | Lemma: this
#
# unit | POS: NOUN | Lemma: unit
#
# is | POS: AUX | Lemma: be
#
# Rs | POS: PROPN | Lemma: Rs
#
# 1.99 | POS: NUM | Lemma: 1.99
#
# Cr | POS: PROPN | Lemma: Cr
#
# . | POS: PUNCT | Lemma: .
#
# The | POS: DET | Lemma: the
#
# built | POS: VERB | Lemma: build
#
# - | POS: PUNCT | Lemma: -
#
# up | POS: ADP | Lemma: up
#
# area | POS: NOUN | Lemma: area
#
# is | POS: AUX | Lemma: be
#
# 2583 | POS: NUM | Lemma: 2583
#
# Square | POS: ADJ | Lemma: square
#
# feet | POS: NOUN | Lemma: foot
#
# . | POS: PUNCT | Lemma: .
#
# There | POS: PRON | Lemma: there
#
# are | POS: VERB | Lemma: be
#
# 4 | POS: NUM | Lemma: 4
#
# bedrooms | POS: NOUN | Lemma: bedroom
#
# and | POS: CCONJ | Lemma: and
#
# 4 | POS: NUM | Lemma: 4
#
# bathroom | POS: NOUN | Lemma: bathroom
#
# . | POS: PUNCT | Lemma: .
#
# It | POS: PRON | Lemma: it
#
# is | POS: AUX | Lemma: be
#
# an | POS: DET | Lemma: an
#
# ideal | POS: ADJ | Lemma: ideal
#
# location | POS: NOUN | Lemma: location
#
# for | POS: ADP | Lemma: for
#
# young | POS: ADJ | Lemma: young
#
# families | POS: NOUN | Lemma: family
#
# with | POS: ADP | Lemma: with
#
# kids | POS: NOUN | Lemma: kid
#
# , | POS: PUNCT | Lemma: ,
#
# as | POS: SCONJ | Lemma: as
#
# this | POS: DET | Lemma: this
#
# property | POS: NOUN | Lemma: property
#
# is | POS: AUX | Lemma: be
#
# close | POS: ADJ | Lemma: close
#
# to | POS: ADP | Lemma: to
#
# Mount | POS: PROPN | Lemma: Mount
#
# Litera | POS: PROPN | Lemma: Litera
#
# Zee | POS: PROPN | Lemma: Zee
#
# School | POS: PROPN | Lemma: School
#
# , | POS: PUNCT | Lemma: ,
#
# OMR | POS: PROPN | Lemma: OMR
#
# , | POS: PUNCT | Lemma: ,
#
# Chennai | POS: PROPN | Lemma: Chennai
#
# , | POS: PUNCT | Lemma: ,
#
# Amelio | POS: PROPN | Lemma: Amelio
#
# Early | POS: PROPN | Lemma: Early
#
# Education | POS: PROPN | Lemma: Education
#
# - | POS: PUNCT | Lemma: -
#
# Siruseri | POS: PROPN | Lemma: Siruseri
#
# , | POS: PUNCT | Lemma: ,
#
# and | POS: CCONJ | Lemma: and
#
# Chennai | POS: PROPN | Lemma: Chennai
#
# Mathematical | POS: PROPN | Lemma: Mathematical
#
# Institute | POS: PROPN | Lemma: Institute
#
# . | POS: PUNCT | Lemma: .
#
# H | POS: PROPN | Lemma: H
#
# ... | POS: PUNCT | Lemma: ...

# %%
m = len(col)
d = {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10}

def fun(doc):
    res = set()
    bhk = None
    rooms = None

    for token in doc:
        word = token.text.lower()
        if token.like_num:
            rooms = token.text


        if word in d:
            rooms = d[word]



        # For Bedrooms
        if word == "bedrooms":
            bhk = "Bedrooms"
            res.add(f"{bhk} {rooms}")

        # For Bathroom(s)
        if word in ['bathroom', 'bathrooms']:
            bhk = "Bathroom"
            res.add(f"{bhk} {rooms}")

    return res

for i in range(m):
    doc = nlp(col[i])
    if(fun(doc) is not None):
      print(fun(doc))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 4'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 4'}
#
# set()
#
# {'Bedrooms 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 6'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bathroom 2'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 0'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 8', 'Bedrooms 6'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 3'}
#
# {'Bathroom 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 4'}
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 4', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 4'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 0'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 5'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 5'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# {'Bathroom 0'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 0'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 3'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 5'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms None'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 5'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 4'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 4'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 6'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 3'}
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# {'Bedrooms 3'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 7'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 10'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 5', 'Bedrooms 7'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 7'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 4'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 1'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 8', 'Bathroom 8'}
#
# {'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 5'}
#
# {'Bathroom 1'}
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 8', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 6'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 10', 'Bathroom 4'}
#
# set()
#
# set()
#
# {'Bedrooms 4'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 10', 'Bathroom 6'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 4', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 8', 'Bathroom 5'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 2', 'Bedrooms 6'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 5'}
#
# {'Bedrooms 2', 'Bathroom 5'}
#
# {'Bathroom 2', 'Bedrooms 6'}
#
# {'Bedrooms 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 5', 'Bedrooms 6'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 4'}
#
# {'Bathroom 3', 'Bedrooms 9'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 4'}
#
# {'Bedrooms 4'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 5'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 8', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bedrooms 8', 'Bathroom 4'}
#
# {'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 4'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 8', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 7', 'Bedrooms 10'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 5'}
#
# {'Bedrooms 8', 'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 4', 'Bedrooms 9'}
#
# {'Bedrooms 6'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 8'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 9', 'Bathroom 9'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 8', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 10', 'Bathroom 8'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 2', 'Bedrooms 6'}
#
# {'Bathroom 1', 'Bathroom 60,000'}
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 10', 'Bathroom 4'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 10', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 9', 'Bathroom 6'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 2', 'Bedrooms 6'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 3', 'Bedrooms 7'}
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 4'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 4'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 2', 'Bedrooms 6'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 7'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# {'Bedrooms 4'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 5'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# {'Bedrooms 2', 'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# set()
#
# {'Bathroom 4'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 5'}
#
# set()
#
# {'Bedrooms 10', 'Bathroom 6'}
#
# set()
#
# {'Bedrooms 8', 'Bathroom 8'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 10', 'Bathroom 4'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# {'Bedrooms 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 2', 'Bedrooms 7'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 8', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# {'Bedrooms 10', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 6', 'Bedrooms 7'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bedrooms 5'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 5'}
#
# {'Bathroom 1'}
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 6', 'Bedrooms 7'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 3', 'Bedrooms 9'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 5'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 4'}
#
# {'Bathroom 1'}
#
# {'Bathroom 4', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bedrooms 5'}
#
# {'Bedrooms 6'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 7'}
#
# set()
#
# {'Bathroom 7', 'Bedrooms 10'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 8', 'Bathroom 8'}
#
# set()
#
# {'Bedrooms 6'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bedrooms 8', 'Bathroom 5'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 8', 'Bathroom 6'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 9', 'Bathroom 9'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 8', 'Bathroom 4'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 2', 'Bedrooms 6'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 6'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 3'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 5', 'Bedrooms 7'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 6', 'Bedrooms 7'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 4'}
#
# {'Bedrooms 10', 'Bathroom 6'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 6'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 7', 'Bedrooms 10'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bathroom 01', 'Bathroom 1st'}
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 8', 'Bedrooms 7'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 8', 'Bathroom 6'}
#
# {'Bedrooms 10', 'Bathroom 6'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 8', 'Bathroom 8'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 10'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 4', 'Bedrooms 7'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 6'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 8', 'Bathroom 5'}
#
# set()
#
# set()
#
# {'Bedrooms 8', 'Bathroom 4'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 9'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 4'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 1'}
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 6'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 10', 'Bathroom 9'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 7'}
#
# {'Bedrooms 8'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 8', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bathroom 3', 'Bedrooms 6'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 4'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3'}
#
# set()
#
# {'Bathroom 3'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 10', 'Bathroom 6'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 5', 'Bathroom 6'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# {'Bathroom 5'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bathroom 2', 'Bedrooms 6'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 8', 'Bedrooms 6'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bathroom 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 5'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 8', 'Bathroom 8'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 5', 'Bathroom 5'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 9', 'Bathroom 9'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 4', 'Bedrooms 7'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 6', 'Bathroom 6'}
#
# {'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 2'}
#
# {'Bathroom 4', 'Bedrooms 5'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 2', 'Bathroom 1'}
#
# set()
#
# {'Bedrooms 10', 'Bathroom 5'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# set()
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# set()
#
# {'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 3', 'Bedrooms 2'}
#
# {'Bedrooms 2'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 3'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bedrooms 5', 'Bathroom 3'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 6'}
#
# {'Bedrooms 3', 'Bathroom 5'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 2'}
#
# {'Bedrooms 4', 'Bathroom 2'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bedrooms 3'}
#
# {'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# {'Bathroom 4', 'Bedrooms 7'}
#
# {'Bedrooms 4', 'Bathroom 3'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 4', 'Bathroom 4'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 0'}
#
# set()
#
# set()
#
# set()
#
# set()
#
# {'Bathroom 1'}
#
# set()
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# {'Bathroom 1'}
#
# {'Bathroom 4', 'Bedrooms 9'}
#
# {'Bathroom 1'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# {'Bathroom 4'}
#
# {'Bedrooms 4'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 5', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 3'}
#
# {'Bedrooms 3', 'Bathroom 1'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 8', 'Bathroom 5'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# set()
#
# set()
#
# {'Bedrooms 2', 'Bathroom 2'}
#
# set()
#
# {'Bathroom 1'}
#
# {'Bathroom 4', 'Bedrooms 7'}
#
# {'Bathroom 1', 'Bedrooms 2'}
#
# {'Bathroom 1'}
#
# set()
#
# {'Bedrooms 3', 'Bathroom 2'}
#
# {'Bathroom 1'}

# %%
df.info()

# %%
df.isnull().sum()
# Out:
# Name              0
# Property Title    0
# Price             0
# Location          0
# Total_Area        0
# Price_per_SQFT    0
# Description       0
# Baths             0
# Balcony           0
# dtype: int64

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Name: 9998 unique values
# Property Title: 6507 unique values
# Price: 891 unique values
# Location: 7050 unique values
# Total_Area: 1774 unique values
# Price_per_SQFT: 2094 unique values
# Description: 14490 unique values
# Baths: 6 unique values
# Balcony: 2 unique values

# %%
def extract_bedrooms_nlp(text):
    text = str(text).lower()
    doc = nlp(text)

    # Dictionary for word → number
    word_to_num = {
        "one": 1, "two": 2, "three": 3, "four": 4, "five": 5,
        "six": 6, "seven": 7, "eight": 8, "nine": 9, "ten": 10,
        "eleven": 11, "twelve": 12
    }

    for token in doc:
        if token.like_num:
            try:
                num = int(token.text) #"3" "2"
            except ValueError:
                num = word_to_num.get(token.text.lower())  # "Three" , "Two"

            if num is None:
                continue

            # Check nearby tokens for bedroom keywords
            next_tokens = [t.text for t in doc[token.i:token.i+3]]
            if any(w in next_tokens for w in ["bhk", "bedroom", "bedrooms", "room", "rooms"]):
                return num
    return None

# %%
def extract_bathrooms_nlp(text):
  if(text.token=='bedroom'):

# %%
df["Num_Bedrooms"] = df["Property Title"].apply(extract_bedrooms_nlp)
print(df[["Property Title", "Num_Bedrooms"]].head(20))
df['Num_Bathrooms']=col.apply(extract_bathrooms_nlp)
print(df[["Description", "Num_Bathrooms"]].head(20)
# Out:
#                                        Property Title  Num_Bedrooms
# 0   4 BHK Flat for sale in Kanathur Reddikuppam, C...           4.0
# 1   10 BHK Independent House for sale in Pozhichal...          10.0
# 2       3 BHK Flat for sale in West Tambaram, Chennai           3.0
# 3   7 BHK Independent House for sale in Triplicane...           7.0
# 4               2 BHK Flat for sale in Avadi, Chennai           2.0
# 5            2 BHK Flat for sale in Siruseri, Chennai           2.0
# 6           2 BHK Flat for sale in Sembakkam, Chennai           2.0
# 7   3 BHK Independent House for sale in Mahindra W...           3.0
# 8       2 BHK Flat for sale in West Tambaram, Chennai           2.0
# 9           1 BHK Flat for sale in Chromepet, Chennai           1.0
# 10  1 BHK Flat for sale in Mahindra World City, Ch...           1.0
# 11       3 BHK Flat for sale in Pallikaranai, Chennai           3.0
# 12     6 BHK Villa for sale in West Mambalam, Chennai           6.0
# 13        2 BHK Flat for sale in Ashok Nagar, Chennai           2.0
# 14        2 BHK Flat for sale in Madambakkam, Chennai           2.0
# 15      3 BHK Flat for sale in Perungalathur, Chennai           3.0
# 16           2 BHK Flat for sale in Padappai, Chennai           2.0
# 17       3 BHK Flat for sale in Nungambakkam, Chennai           3.0
# 18          4 BHK Flat for sale in Muttukadu, Chennai           4.0
# 19  2 BHK Independent House for sale in Pozhichalu...           2.0
